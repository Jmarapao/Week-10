# %% [markdown]
# <a href="https://colab.research.google.com/github/Jmarapao/Week-10/blob/main/APs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import xml.etree.ElementTree as ET  # for parsing XML


tree = ET.parse('inventory 1.xml')

# getting the parent tag of
# the xml document
root = tree.getroot()

#-------------------------------------------------------------
i=1
mylist= []
y = 0
Bool = 0
while i < len(root):
  parcer = root[i][0].text
  x = parcer.split("-")
  try:
   mylist.append(x[0]+' '+x[1])
  except:
    mylist.append(x[0])
  print(i)
  i=i+1
if mylist:
    mylist.sort()
    last = mylist[-1]
    for i in range(len(mylist)-2, -1, -1):
        if last == mylist[i]:
            del mylist[i]
        else:
            last = mylist[i]
print(mylist)

# %%
#-----------Packages--------------------------
import json
import os
import requests
#!pip install xmltodict # use this when xml to json is not working
import xmltodict
import xml.etree.ElementTree as ET
#-----
def Get_ParentZone(furl):
  url = furl
  payload = ""
  headers = {
    'Authorization': 'Bearer '+BToken,
    'Cookie': 'AWSALB=Nl+KxVuU9qnSYdpQVXIKu+dKHoDuQ2GfJMmpooRrmghW47drd6tpScL+8V/8pbVbm4aZNfg3DoMv+E2RirNtr9yZwnAO/yZC/eN+bI6euBs9coX3XTayuKZOBku7; AWSALBCORS=Nl+KxVuU9qnSYdpQVXIKu+dKHoDuQ2GfJMmpooRrmghW47drd6tpScL+8V/8pbVbm4aZNfg3DoMv+E2RirNtr9yZwnAO/yZC/eN+bI6euBs9coX3XTayuKZOBku7'
  }
  response = requests.request("GET", url, headers=headers, data=payload)

  if response.text==None:
    print("Could not find parent zones. It may be because the get_url_zone is wrong")
  else:
    i=0
    res = response.json()

    while i < len(res):
      BuildingName = res[i]['name']
      parentids = res[i]['parentId']
      i=i+1

def xml_sorter(xml_file):
  tree = ET.parse(xml_file)
  root = tree.getroot()
  i=1
  mylist= []
  y = 0
  Bool = 0
  while i < len(root):
    parcer = root[i][0].text
    x = parcer.split("-")
    try:
      mylist.append(x[0]+' '+x[1])
    except:
      mylist.append(x[0])
    i=i+1
  if mylist:
    mylist.sort()
    last = mylist[-1]
    for i in range(len(mylist)-2, -1, -1):
        if last == mylist[i]:
            del mylist[i]
        else:
            last = mylist[i]


  print("starting parse")

  print("root")
# getting the parent tag of
# the xml document


  while y < len(mylist):

    parcer = mylist[y]
    x = parcer.split(" ")
    if x[0]=='Old':
      Building = 'JC'
      parentid= '06091b4e-77fe-4fb7-9e27-b9b11595df76'
    elif x[0]=='LL' or x[0]==None:
     Building = None
     parentid= '4a21a6b8-b3eb-45c7-a3b8-984fbb7fcf72'
    else:
      Building = x[0]
      parentid = '4a21a6b8-b3eb-45c7-a3b8-984fbb7fcf72'
    try:
      Building = Building, x[1]
      if x[1]=="LL":
        elevation = "-100"
      else:
        elevation = x[1]+"00"
    except:
      elevation = '100'
      Building = Building+' 1'


      for i in len(parentids):
        if BuildingName==x[0]:
          parentid = parentids[i]
          payload = json.dumps({
            "lng": None,
            "lat": None,
            "address": None,
            "primaryPhone": "(800) 521-1146",
            "secondaryPhone": "(800) 521-1146",
            "excludeFullName": False,
            "buildingName": Building,
            "elevation": elevation,
            "canCpbSelect": True,
            "overrideCountdownTimer": False,
            "countdownTimer": 0,
            "name": x[1],
            "id": None,
            "parentId": parentid
          })
          headers = {
            'Content-Type': 'application/json',
            'Authorization': 'Bearer e7fa9cb0-b6c3-414f-aa9b-33aa1267c3d6',
            'Cookie': 'AWSALB=yGZ99K9eDcpCmjhrj0SpEe2jF4TGfeOBKrYcluO+mIlbBnI0+c9GSYv2Gn8RUIZrPLS6t55VxHGbUxVg2UkeqDIdHP0PHRgfmF76pBl5p65lfBWyftZs7sg4B/x4; AWSALBCORS=yGZ99K9eDcpCmjhrj0SpEe2jF4TGfeOBKrYcluO+mIlbBnI0+c9GSYv2Gn8RUIZrPLS6t55VxHGbUxVg2UkeqDIdHP0PHRgfmF76pBl5p65lfBWyftZs7sg4B/x4; publicsafetycloud_session=CfDJ8JzI8LqKwS1Lr7Qfi3njWyAPRpxv7texUlV7krIypWStyPQ06ON0LWQAQSQZH9W5YrmV7Jv5DxotE%2BkYfb4M2kSn8xQPvIaCBonLPm040oGqQGxonYdBrian9WVCO4WIKC%2FfICaY7w2Ly%2FrOe19PtW%2Bp1qyARkczd41fGaX14jqX'
          }
          response = requests.request("POST", get_zone_url, headers=headers, data=payload)
    y=y+1

def json_export(json_file):
  with open(json_file, "r") as f:
    data = json.load(f)
  i=0
  for name in data['inventory']['AP']:
    try:
      macs = [data['inventory']['AP'][i]['radio_1']['bss_macs']['bss_mac'][0]['mac'],
          data['inventory']['AP'][i]['radio_1']['bss_macs']['bss_mac'][1]['mac'],
          data['inventory']['AP'][i]['radio_2']['bss_macs']['bss_mac'][0]['mac'],
          data['inventory']['AP'][i]['radio_2']['bss_macs']['bss_mac'][1]['mac']]
    except:
      macs = ["null"]
    for mac in macs:
        alias = data['inventory']['AP'][i]['name']
        parcer = data['inventory']['AP'][i]['name']
        x = parcer.split("-")
        if x[0] =='IT Test AP':
          zone = "Malone Test Account Error"
        elif x[0] == "LL" and x[1]=="LL":
            zone = "Malone Test Account Error"
        elif x[1] =="JC":
            zone = "Malone Test Account "+ x[1] +' '+ x[2]
        else:
            zone = "Malone Test Account "+ x[0] +' '+ x[1]
        try:
          name = x[0]+' '+x[1]+' Test'
        except:
          name = x[0]+' Test'
        if (data['inventory']['AP'][i]['name']=='IT Test AP'):
          note = "THIS IS THE TEST AP"
        else:
          note = None
        payload = json.dumps([{
          "alias":alias,
          "lat": None,
          "lng": None,
          "securityZoneName": zone,
          "name": name,
          "bssid": mac,
          "macAddress": mac,
          "notes": note
        }])

        headers = {
          'Content-Type': 'application/json',
          'Authorization': 'Bearer '+BToken,
          'Cookie': 'AWSALB=yGZ99K9eDcpCmjhrj0SpEe2jF4TGfeOBKrYcluO+mIlbBnI0+c9GSYv2Gn8RUIZrPLS6t55VxHGbUxVg2UkeqDIdHP0PHRgfmF76pBl5p65lfBWyftZs7sg4B/x4; AWSALBCORS=yGZ99K9eDcpCmjhrj0SpEe2jF4TGfeOBKrYcluO+mIlbBnI0+c9GSYv2Gn8RUIZrPLS6t55VxHGbUxVg2UkeqDIdHP0PHRgfmF76pBl5p65lfBWyftZs7sg4B/x4; publicsafetycloud_session=CfDJ8JzI8LqKwS1Lr7Qfi3njWyAPRpxv7texUlV7krIypWStyPQ06ON0LWQAQSQZH9W5YrmV7Jv5DxotE%2BkYfb4M2kSn8xQPvIaCBonLPm040oGqQGxonYdBrian9WVCO4WIKC%2FfICaY7w2Ly%2FrOe19PtW%2Bp1qyARkczd41fGaX14jqX'
        }
        response = requests.request("POST", furl, headers=headers, data=payload)
        #print(payload)
        #print(response)
    i=i+1
BToken = 'e7fa9cb0-b6c3-414f-aa9b-33aa1267c3d6'#Bearer Token
furl = "https://portal.publicsafetycloud.net/accesspointapi"
get_zone_url = 'https://portal.publicsafetycloud.net/securityzone'
filePath = ''
i=0
for root, dirs, files in os.walk('./'+filePath):
    for file in files:

        if file.endswith('.xml'):
          i=i+1
          with open(file) as xml_file:
            data_dict = xmltodict.parse(xml_file.read())
            json_data = json.dumps(data_dict)
            with open("data.json", "w") as json_file:
              json_file.write(json_data)
              Get_ParentZone(get_zone_url)
              print("Get_Parent Complete")
              xml_sorter(file)
              print("sort Complete")
              json_export('data.json')
              print("data",i,"Complete")

# %%
from os import name
import json
import xml.etree.ElementTree as ET  # for parsing XML

y=0


# getting the parent tag of
# the xml document


#-------------------------------------------------------------

def xml_sorter(xml_file):
  tree = ET.parse(xml_file)
  root = tree.getroot()
  i=1
  mylist= []
  y = 0
  Bool = 0
  while i < len(root):
    parcer = root[i][0].text
    x = parcer.split("-")
    try:
      mylist.append(x[0]+' '+x[1])
    except:
      mylist.append(x[0])
    i=i+1
  if mylist:
    mylist.sort()
    last = mylist[-1]
    for i in range(len(mylist)-2, -1, -1):
        if last == mylist[i]:
            del mylist[i]
        else:
            last = mylist[i]

def Building(xml_file):
  y=0
  while y < len(mylist):

    parcer = mylist[y]
    x = parcer.split(" ")
  if x[0]=='CC':
    Building = 'CC - Brehme Centennial Center'
    parentid= 'bbc80253-5652-44ad-aaea-2134f05fada7'
  elif x[0]=='FHN':
     Building = 'FHN - Founders Hall'
     parentid= '70c2eb59-4888-4358-b363-3ea53610e836'
  elif x[0]=='FHS':
      Building = 'FHS - Founders Hall'
      parentid= 'f31f0e43-c954-4615-9acf-64b9fe9556dc'
  elif x[0]=='CL':
    Building = 'CL - Everett Cattell Library'
    parentid= '6db84e10-8c0e-4184-b7a8-73d3c0501773'
  elif x[0]=='HH':
     Building = 'HH - Heritage Hall'
     parentid= '0df7d629-febb-466f-85a5-590747095549'
  elif x[0]=='JC':
      Building = 'JC - Ronald and Marge Johnson Center'
      parentid= '06091b4e-77fe-4fb7-9e27-b9b11595df76'
  elif x[0]=='LH':
      Building = 'LH - Laura Haviland Hall'
      parentid= '58972bc3-e2bc-464a-a402-a97bfa935d3e'
  elif x[0]=='Old':
      Building = 'JC - Ronald and Marge Johnson Center'
      parentid= '06091b4e-77fe-4fb7-9e27-b9b11595df76'
  elif x[0]=='LL':
     Building = 'LL'
     parentid= '4a21a6b8-b3eb-45c7-a3b8-984fbb7fcf72'
  else:
    Building = 'null'
    parentid = '4a21a6b8-b3eb-45c7-a3b8-984fbb7fcf72'
  print('{')
  print('"lng": null,')
  print('"lat": null,')
  print('"address": null,')
  print('"primaryPhone": "(800) 521-1146",')
  print('"secondaryPhone": "(800) 521-1146",')
  print('"excludeFullName": false,')

  try:
    print('"buildingName": "', Building, x[1],'",')
    if x[1]=="LL":
      elevation = "-100"
    else:
      elevation = x[1]+"00"
    print('"elevation":', elevation, ',')
    print('"canCpbSelect": true,')
    print('"overrideCountdownTimer": false,')
    print('"countdownTimer": 0,')
    print('"name": "',x[1],'",')
  except:
    print('"buildingName": "', Building,'1",')
    print('"elevation": 100,')
    print('"canCpbSelect": true,')
    print('"overrideCountdownTimer": false,')
    print('"countdownTimer": 0,')
    print('"name":',x[1],',')
  print('"id": null,')
  print('"parentId":"',parentid,'"')
  print('}')


BToken = '479a772b-96cf-41de-bacc-9c2b91cefd3d'#Bearer Token
url = "https://portal.publicsafetycloud.net/securityzone"
get_zone_url = 'https://portal.publicsafetycloud.net/securityzone'
xml_sorter('inventory 1.xml')
Building('inventory 1.xml')

# %%
import xml.etree.ElementTree as ET  # for parsing XML


tree = ET.parse('inventory 1.xml')

# getting the parent tag of
# the xml document
root = tree.getroot()

#-------------------------------------------------------------
i=1
mylist= []
y = 0
Bool = 0
import requests

url = "https://portal.publicsafetycloud.net/accesspointapi?bssid"

payload = ""
headers = {
  'Authorization': 'Bearer 479a772b-96cf-41de-bacc-9c2b91cefd3d',
  'Cookie': 'AWSALB=PmhEucKeUoblGQQgIU1OntJFrcXGrGqkyW9rbC5IVUR06B+qrLimN9zcuU77rpJyMhi1VUOJEBWMQ+cr3oG346BDfy3ng0h1hevrl96AyjXXu2YpvgQ2qcTntunU; AWSALBCORS=PmhEucKeUoblGQQgIU1OntJFrcXGrGqkyW9rbC5IVUR06B+qrLimN9zcuU77rpJyMhi1VUOJEBWMQ+cr3oG346BDfy3ng0h1hevrl96AyjXXu2YpvgQ2qcTntunU; publicsafetycloud_session=CfDJ8JzI8LqKwS1Lr7Qfi3njWyBEz1jv0QZjiwdwyTNNwNXFsxc3aHNFYaHtFyWtdZnL6NlVQCejIZvZ8kGBznjgfcInzBtkjktyN2cfTmnAnCOLfgKESZCn8B4jDz7Sq42MwwUP7kzN1Eg9s4CKMWBaQN%2FxLwwgK4aNIbgYPMiWpa%2Fs'
}

response = requests.request("GET", url, headers=headers, data=payload)
data=response.json()
print(data[0])
i=0
while i < len(data):

      print('"'+data[i]['bssid']+'",')
      i=i+1
# Out:
# {'alias': 'CC-2-HDC-E', 'name': 'CC 2 Test', 'ipv4': None, 'lat': None, 'lng': None, 'macAddress': ' 20:B3:99:D8:06:01 ', 'bssid': '20:b3:99:d8:06:01', 'zones': '4c83cdc0-245b-4a8c-9093-2a04f5c29358', 'securityZoneId': '4c83cdc0-245b-4a8c-9093-2a04f5c29358', 'nearestApFormatted': None, 'approximateLocation': False, 'ssid': None, 'connected': False, 'signalStrength': 0.0, 'createdAt': '2023-06-13T18:52:17', 'createdBy': 0, 'modifiedAt': '2023-06-13T18:52:17', 'modifiedBy': 0, 'notes': None, 'nearestAp': None, 'point': None, 'institutionId': 779, 'ipv6': None, 'securityZoneName': None, 'id': 621653}
# "20:b3:99:d8:06:01",
# "20:b3:99:d8:06:02",
# "20:b3:99:d8:06:09",
# "20:b3:99:d8:06:0a",
# "20:b3:99:d8:0c:e1",
# "20:b3:99:d8:0c:e2",
# "20:b3:99:d8:0c:e9",
# "20:b3:99:d8:0c:ea",
# "20:b3:99:d8:0e:61",
# "20:b3:99:d8:0e:62",
# "20:b3:99:d8:0e:69",
# "20:b3:99:d8:0e:6a",
# "dc:b8:08:3f:02:20",
# "dc:b8:08:3f:02:21",
# "dc:b8:08:3f:02:30",
# "dc:b8:08:3f:02:31",
# "dc:b8:08:3f:06:80",
# ...

# %%
import requests

url = "https://portal.publicsafetycloud.net/securityzone"

payload = ""
headers = {
  'Authorization': 'Bearer 479a772b-96cf-41de-bacc-9c2b91cefd3d',
  'Cookie': 'AWSALB=Nl+KxVuU9qnSYdpQVXIKu+dKHoDuQ2GfJMmpooRrmghW47drd6tpScL+8V/8pbVbm4aZNfg3DoMv+E2RirNtr9yZwnAO/yZC/eN+bI6euBs9coX3XTayuKZOBku7; AWSALBCORS=Nl+KxVuU9qnSYdpQVXIKu+dKHoDuQ2GfJMmpooRrmghW47drd6tpScL+8V/8pbVbm4aZNfg3DoMv+E2RirNtr9yZwnAO/yZC/eN+bI6euBs9coX3XTayuKZOBku7'
}

response = requests.request("GET", url, headers=headers, data=payload)

if response.text==None:
    print("Could not find parent zones. It may be because the get_url_zone is wrong")
else:
    i=0
    res = response.json()

    while i < len(res):
      BuildingName = res[i]['name']
      parentids = res[i]['parentId']
      i=i+1
